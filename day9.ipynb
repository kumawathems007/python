# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import skimage as ski

# %%
img=cv2.imread('img1.jpeg')
img.shape
# Out:
# (600, 900, 3)

# %%
# Image type converstion 
# Geometric transformation
# Image Arithmetic / Brightness. contrast Adujestments
     # addition
     # subtration 
    # multiplication
    # Divison
    # Brightness & Contrast Adujustment

# Morpholog  
#

# %%
plt.imshow(img[:,:,::-1])

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_gray.shape
plt.imshow(img_gray,cmap='gray')

# %%
th ,img_bin=cv2.threshold(img_gray, 70,255, cv2.THRESH_BINARY)
img_bin.shape
# Out:
# (600, 900)

# %%
plt.imshow(img_bin, cmap='gray')

# %%
# croping
plt.imshow(img_bin[100:200,200:400])  #,cmap='gray'

# %%
x,y,w,h=(50,150,80,140)
plt.imshow(img[y:y+h, x:x+w, ::-1])
 

x1,y1,x2,y2=(50,150,270,210)
plt.imshow(img[y1:y2, x1:x2, ::-1])

# %%
# Scaling
img_large=cv2.resize(img,(1500,1500), interpolation=cv2.INTER_CUBIC)
img_large.shape
# Out:
# (1500, 1500, 3)

# %%
plt.imshow(img_large[:,:,::-1])

# %%
img_large=cv2.resize(img,(1500,1500), interpolation=cv2.INTER_CUBIC)
img_large.shape

img_small=cv2.resize(img,(0,0), fx=0.25, fy=0.25, interpolation=cv2.INTER_CUBIC)
img_small.shape
# Out:
# (150, 225, 3)

# %%
img_90=cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img_90)

# %%
img_x=ski.transform.rotate(img, -30)
plt.imshow(img_x[:,:,::-1])

# %%
# Arithmetic
plt.subplot(1,3,1)
plt.title('Original')
plt.imshow(img[:,:,::-1]); plt.axis('off')
plt.subplot(1,3,2)
plt.title('Beightest')
plt.imshow(img[:,:,::-1]+20); plt.axis('off')
plt.subplot(1,3,3)
plt.title('Drakened')
plt.imshow(img[:,:,::-1]-20); plt.axis('off')
# Out:
# (-0.5, 899.5, 599.5, -0.5)

# %%
plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.subplot(1,2,2)
img_blur=cv2.medianBlur(img,5)
plt.imshow(img_blur[:,:,::-1])
plt.show()


plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.subplot(1,2,2)
img_kernel=np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])

img_shrp=cv2.filter2D(img, ddepth=-1, kernel=shrp_kernel )
plt.imshow(img_sharp[:,:,::-1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Lenovo\Desktop\python AIDP\day9.ipynb Cell 16 in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Desktop/python%20AIDP/day9.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> plt.subplot(1,2,2)
#      <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Desktop/python%20AIDP/day9.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a> img_kernel=np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Desktop/python%20AIDP/day9.ipynb#X21sZmlsZQ%3D%3D?line=13'>14</a> img_shrp=cv2.filter2D(img, ddepth=-1, kernel=shrp_kernel )
#      <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Desktop/python%20AIDP/day9.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a> plt.imshow(img_sharp[:,:,::-1])
#      <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Desktop/python%20AIDP/day9.ipynb#X21sZmlsZQ%3D%3D?line=15'>16</a> plt.show()
#
# NameError: name 'shrp_kernel' is not defined
